# %%
from fastai.vision.all import *
import fastai
import timm
import albumentations as A

# In[2]:


import torch
torch.cuda.set_device(1)

# %%
import os
def create_csvValid(path):
    output_path = os.path.join(path,"..","df_train.csv")
    if (os.path.exists(output_path)):
        output_path_csv = open(output_path, "a")
    else:
        output_path_csv = open(output_path, "w")
        head = "images, class\n"
        output_path_csv.write(head)

    
    lista_archivos = list(os.walk(path))
    lista_archivos.sort()
    for carpeta in lista_archivos:
#         print(carpeta[0])
        video = carpeta[0].split(os.path.sep)[-1]
        for files in carpeta[2]:
            if "images.csv" in files:
                leer = open(os.path.join(carpeta[0],files))
                leer.readline()
                for l in leer:
                    output_path_csv.write(video+os.path.sep+"images"+os.path.sep+l)
#                     print(l)

# %%
create_csvValid("./dataset_split_38frames/train")

# %%
import pandas as pd
import numpy as np

dfValid = pd.read_csv('./dataset_split_38frames/df_train.csv')

dfTest = pd.read_csv('./dataset_split_38frames/df_test.csv')


# In[5]:


# prueba = dfValid


# prueba = prueba.iloc[np.random.permutation(len(prueba))]
# prueba = prueba[0:int(len(prueba)*0.1)]
# # In[6]:
# # Aquí debería hacer dos df diferentes. Uno para entrenamiento y otro para validación. En este caso 
# # usa para entrenar el set de entrenamiento y validación. Imagino que la división la hará por programa
# # dfValid = dfValid[(dfValid.set == 'training') | (dfValid.set == 'validation')]




# # Hay que modificar esto para que haya set de validación. Hacer un vector random y que esté entre las primeras 
# # 0.1 posiciones si está se devuelve 
# def is_valid(path):
#     name = path[0]
# #     return (dfValid[dfValid['challenge_id']==name])['set'].values[0]=='validation'
#     return (dfValid[dfValid['images']==name]).values[0] in prueba.images.values
    
# # In[13]:

# def get_class(path):
#     name = path[0]
#     return (dfValid[dfValid['images']==name])['class']

# %%
def get_dls(presize=50,size=38,M=0,bs=512):
    db = DataBlock(blocks = (ImageBlock, CategoryBlock),
             splitter=RandomSplitter(),
             get_x = ColReader(0,pref="./dataset_split_38frames/train/",suff='.jpg'),
             get_y=ColReader(1),
             item_tfms = [Resize(presize)], # CropPad(200,200)
             batch_tfms=[*aug_transforms(size=size, min_scale=0.75,do_flip=False,flip_vert=False,
                  max_rotate=0.,max_zoom=1.1, max_warp=0.05,p_affine=0.9, p_lighting=0.8), 
                         Normalize.from_stats(*imagenet_stats)])
    dls = db.dataloaders(dfValid.values,bs=bs)
    return dls

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    #EarlyStoppingCallback(patience=5),
    SaveModelCallback(fname='resnest50d',monitor='cohen_kappa_score'),
    ReduceLROnPlateau(patience=10)
]

# %%
dlsTrain3 = get_dls()


learn = Learner(dlsTrain3,timm.create_model('resnest50d',num_classes=13,pretrained=True),
                metrics=[accuracy,CohenKappa(weights='quadratic')],cbs=callbacks,
                loss_func= LabelSmoothingCrossEntropyFlat()).to_fp16()

# %%
learn.lr_find()
# Out:
# SuggestedLRs(valley=0.0002754228771664202)

# %%
learn.fine_tune(100,base_lr=3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>cohen_kappa_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.309630</td>
#       <td>1.870166</td>
#       <td>0.461740</td>
#       <td>0.565608</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with cohen_kappa_score value: 0.5656078228255161.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>cohen_kappa_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.130025</td>
#       <td>1.096615</td>
#       <td>0.740248</td>
#       <td>0.873930</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.065664</td>
#       <td>1.082854</td>
#       <td>0.752626</td>
#       <td>0.871452</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.013105</td>
#       <td>1.036512</td>
#       <td>0.775131</td>
#       <td>0.881717</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.962555</td>
#       <td>1.017156</td>
#       <td>0.781320</td>
#       <td>0.859431</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.918443</td>
#       <td>1.033562</td>
#       <td>0.782446</td>
#       <td>0.888412</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.889345</td>
#       <td>0.972504</td>
#       <td>0.801951</td>
#       <td>0.890743</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0
td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.608521</td>
#       <td>1.096783</td>
#       <td>0.787134</td>
#       <td>0.911309</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.610281</td>
#       <td>1.018077</td>
#       <td>0.823143</td>
#       <td>0.912269</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.604680</td>
#       <td>0.979704</td>
#       <td>0.829707</td>
#       <td>0.914631</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.603810</td>
#       <td>1.013982</td>
#       <td>0.821455</td>
#       <td>0.920471</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.600346</td>
#       <td>1.009254</td>
#       <td>0.820705</td>
#       <td>0.919615</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.599360</td>
#       <td>0.941041</td>
#       <td>0.846399</td>
#       <td>0.907970</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.594193</td>
#       <td>0.969447</td>
#       <td>0.842648</td>
#       <td>0.922795</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.591931</
# Better model found at epoch 0 with cohen_kappa_score value: 0.873930384314535.
# Better model found at epoch 2 with cohen_kappa_score value: 0.8817173071044003.
# Better model found at epoch 4 with cohen_kappa_score value: 0.8884116902442605.
# Better model found at epoch 5 with cohen_kappa_score value: 0.8907426368607655.
# Better model found at epoch 6 with cohen_kappa_score value: 0.8988260150880198.
# Better model found at epoch 8 with cohen_kappa_score value: 0.9000519949637065.
# Better model found at epoch 13 with cohen_kappa_score value: 0.9032556160257383.
# Better model found at epoch 14 with cohen_kappa_score value: 0.9053377427411987.
# Better model found at epoch 18 with cohen_kappa_score value: 0.9095652525468717.
# Better model found at epoch 28 with cohen_kappa_score value: 0.9190365206049369.
# Epoch 31: reducing lr to 0.00014970538993278412
# Better model found at epoch 34 with cohen_kappa_score value: 0.9263180102575788.
# Better model found at epoch 40 with cohen_kappa_score value: 0.928192493485128.
# Epoch 50: reducing lr to 0.00011915060074760633
# Better model found at epoch 51 with cohen_kappa_score value: 0.9306828516365542.
# Better model found at epoch 53 with cohen_kappa_score value: 0.9338726111219144.
# Better model found at epoch 56 with cohen_kappa_score value: 0.9341124920072512.
# Better model found at epoch 57 with cohen_kappa_score value: 0.9350995814647167.
# Better model found at epoch 64 with cohen_kappa_score value: 0.9368961223341907.
# Better model found at epoch 69 with cohen_kappa_score value: 0.9396740534952922.
# Better model found at epoch 73 with cohen_kappa_score value: 0.9400724791995597.
# Better model found at epoch 77 with cohen_kappa_score value: 0.9411023271916445.
# Better model found at epoch 82 with cohen_kappa_score value: 0.9415590916477117.
# Better model found at epoch 83 with cohen_kappa_score value: 0.9445132032154545.

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(12,12),dpi=60)

# %%
dbTest = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_x = ColReader(0,pref="./dataset_split_38frames/test/",suff='.jpg'),
                 get_y=ColReader(1),
                 item_tfms = Resize(100),
                 batch_tfms=[*aug_transforms(size=77, min_scale=0.75), Normalize.from_stats(*imagenet_stats)])
dlsTest = dbTest.dataloaders(dfTest.values,bs=128)



# dbTest = DataBlock(blocks = (ImageBlock, CategoryBlock),get_items=get_image_files, 
#                    splitter=GrandparentSplitter(valid_name='test'),get_y=parent_label, 
#                    item_tfms = Resize(512),batch_tfms=[*aug_transforms(size=256, min_scale=0.75), 
#                    Normalize.from_stats(*imagenet_stats)])
# dlsTest = dbTest.dataloaders("./dataset_split_77frames/df_test.csv",bs=32)

# %%
learn.dls = dlsTest
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(12,12),dpi=60)

# %%
# learn.validate()
# Out:
# /home/jonathan/.virtualenvs/segmentation/lib/python3.6/site-packages/fastprogress/fastprogress.py:74: UserWarning: Your generator is empty.
#   warn("Your generator is empty.")
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-631604a2e07b> in <module>
# ----> 1 learn.validate()
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/fastai/learner.py in validate(self, ds_idx, dl, cbs)
#     233     def validate(self, ds_idx=1, dl=None, cbs=None):
#     234         if dl is None: dl = self.dls[ds_idx]
# --> 235         with self.validation_context(cbs=cbs): self._do_epoch_validate(ds_idx, dl)
#     236         return getattr(self, 'final_record', None)
#     237
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/fastcore/xtras.py in __exit__(self, *args, **kwargs)
#     471     def __init__(self, mgrs): self.default,self.stack = L(mgrs),ExitStack()
#     472     def __enter__(self): self.default.map(self.stack.enter_context)
# --> 473     def __exit__(self, *args, **kwargs): self.stack.__exit__(*args, **kwargs)
#     474
#     475 # Cell
#
# /usr/lib/python3.6/contextlib.py in __exit__(self, *exc_details)
#     378                 # set-up context
#     379                 fixed_ctx = exc_details[1].__context__
# --> 380                 raise exc_details[1]
#     381             except BaseException:
#     382                 exc_details[1].__context__ = fixed_ctx
#
# /usr/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      97                 value = type()
#      98             try:
# ---> 99                 self.gen.throw(type, value, traceback)
#     100             except StopIteration as exc:
#     101                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/fastai/learner.py in replacing_yield(o, attr, val)
#      22     "Context manager to temporarily replace an attribute"
#      23     old = getattr(o,attr)
# ---> 24     try:     yield setattr(o,attr,val)
#      25     finally: setattr(o,attr,old)
#      26
#
# /usr/lib/python3.6/contextlib.py in __exit__(self, *exc_details)
#     363             cb = self._exit_callbacks.pop()
#     364             try:
# --> 365                 if cb(*exc_details):
#     366                     suppressed_exc = True
#     367                     pending_raise = False
#
# /usr/lib/python3.6/contextlib.py in _exit_wrapper(*exc_details)
#     282         """Helper to correctly register callbacks to __exit__ methods"""
#     283         def _exit_wrapper(*exc_details):
# --> 284             return cm_exit(cm, *exc_details)
#     285         _exit_wrapper.__self__ = cm
#     286         self.push(_exit_wrapper)
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/fastai/learner.py in __exit__(self, exc_type, exc_value, tb)
#     223     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
#     224     def __enter__(self): self(_before_epoch); return self
# --> 225     def __exit__(self, exc_type, exc_value, tb): self(_after_epoch)
#     226
#     227     def validation_context(self, cbs=None, inner=False):
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/fastai/learner.py in __call__(self, event_name)
#     139
#     140     def ordered_cbs(self, event): return [cb for cb in self.cbs.sorted('order') if hasattr(cb, event)]
# --> 141     def __call__(self, event_name): L(event_name).map(self._call_one)
#     142
#     143     def _call_one(self, event_name):
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/fastcore/foundation.py in map(self, f, gen, *args, **kwargs)
#     153     def range(cls, a, b=None, step=None): return cls(range_of(a, b=b, step=step))
#     154
# --> 155     def map(self, f, *args, gen=False, **kwargs): return self._new(map_ex(self, f, *args, gen=gen, **kwargs))
#     156     def argwhere(self, f, negate=False, **kwargs): return self._new(argwhere(self, f, negate, **kwargs))
#     157     def argfirst(self, f, negate=False): return first(i for i,o in self.enumerate() if f(o))
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/fastcore/basics.py in map_ex(iterable, f, gen, *args, **kwargs)
#     696     res = map(g, iterable)
#     697     if gen: return res
# --> 698     return list(res)
#     699
#     700 # Cell
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/fastcore/basics.py in __call__(self, *args, **kwargs)
#     681             if isinstance(v,_Arg): kwargs[k] = args.pop(v.i)
#     682         fargs = [args[x.i] if isinstance(x, _Arg) else x for x in self.pargs] + args[self.maxi+1:]
# --> 683         return self.func(*fargs, **kwargs)
#     684
#     685 # Cell
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/fastai/learner.py in _call_one(self, event_name)
#     143     def _call_one(self, event_name):
#     144         if not hasattr(event, event_name): raise Exception(f'missing {event_name}')
# --> 145         for cb in self.cbs.sorted('order'): cb(event_name)
#     146
#     147     def _bn_bias_state(self, with_bias): return norm_bias_params(self.model, with_bias).map(self.opt.state)
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/fastai/callback/core.py in __call__(self, event_name)
#      43                (self.run_valid and not getattr(self, 'training', False)))
#      44         res = None
# ---> 45         if self.run and _run: res = getattr(self, event_name, noop)()
#      46         if event_name=='after_fit': self.run=True #Reset self.run to True at each end of fit
#      47         return res
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/fastai/callback/tracker.py in after_epoch(self)
#      79             if (self.epoch%self.every_epoch) == 0: self._save(f'{self.fname}_{self.epoch}')
#      80         else: #every improvement
# ---> 81             super().after_epoch()
#      82             if self.new_best:
#      83                 print(f'Better model found at epoch {self.epoch} with {self.monitor} value: {self.best}.')
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/fastai/callback/tracker.py in after_epoch(self)
#      35     def after_epoch(self):
#      36         "Compare the last value to the best up to now"
# ---> 37         val = self.recorder.values[-1][self.idx]
#      38         if self.comp(val - self.min_delta, self.best): self.best,self.new_best = val,True
#      39         else: self.new_best = False
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/fastcore/foundation.py in __getitem__(self, idx)
#     109     def _xtra(self): return None
#     110     def _new(self, items, *args, **kwargs): return type(self)(items, *args, use_list=None, **kwargs)
# --> 111     def __getitem__(self, idx): return self._get(idx) if is_indexer(idx) else L(self._get(idx), use_list=None)
#     112     def copy(self): return self._new(self.items.copy())
#     113
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/fastcore/foundation.py in _get(self, i)
#     113
#     114     def _get(self, i):
# --> 115         if is_indexer(i) or isinstance(i,slice): return getattr(self.items,'iloc',self.items)[i]
#     116         i = mask2idxs(i)
#     117         return (self.items.iloc[list(i)] if hasattr(self.items,'iloc')
#
# IndexError: list index out of range

# %%
# learn.export(fname='resnetrsRandAugLS_77frames.pkl')
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# <ipython-input-35-2e2ba772d7b1> in <module>
# ----> 1 learn.export(fname='efficientnet-B0_77frames.pkl')
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/fastai/learner.py in export(self, fname, pickle_module, pickle_protocol)
#     373         #To avoid the warning that come from PyTorch about model not being checked
#     374         warnings.simplefilter("ignore")
# --> 375         torch.save(self, self.path/fname, pickle_module=pickle_module, pickle_protocol=pickle_protocol)
#     376     self.create_opt()
#     377     if state is not None: self.opt.load_state_dict(state)
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     370         if _use_new_zipfile_serialization:
#     371             with _open_zipfile_writer(opened_file) as opened_zipfile:
# --> 372                 _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     373                 return
#     374         _legacy_save(obj, opened_file, pickle_module, pickle_protocol)
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol)
#     474     pickler = pickle_module.Pickler(data_buf, protocol=pickle_protocol)
#     475     pickler.persistent_id = persistent_id
# --> 476     pickler.dump(obj)
#     477     data_value = data_buf.getvalue()
#     478     zip_file.write_record('data.pkl', data_value, len(data_value))
#
# PicklingError: Can't pickle typing.Callable[..., typing.Any]: it's not the same object as typing.Callable

# %%
learn1 = Learner(dlsTrain3,timm.create_model('resnest50d',num_classes=13,pretrained=True),
                metrics=[accuracy,CohenKappa(weights='quadratic')]).to_fp16()

# %%
learn1.load("resnest50d")
# Out:
# /home/jonathan/.virtualenvs/segmentation/lib/python3.6/site-packages/fastai/learner.py:56: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")

# %%
learn1.export("resnest50d_38frames.pkl")

# %%
learn1.validate()
# Out:
# (#3) [0.4979032278060913,0.8782820701599121,0.9445132032154545]

# %%
preds,gt = learn1.tta()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>

# %%
from sklearn.metrics import accuracy_score, top_k_accuracy_score
accuracy_score(np.argmax(preds,axis=1),gt)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-47-1d0d847e12be> in <module>
# ----> 1 from sklearn.metrics import accuracy_score, top_k_accuracy_score
#       2 accuracy_score(np.argmax(preds,axis=1),gt)
#       3 top_k_accuracy_score(np.argmax(preds,axis=1),gt)
#
# ImportError: cannot import name 'top_k_accuracy_score'
